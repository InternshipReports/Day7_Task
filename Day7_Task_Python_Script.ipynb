# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("sales.db")

# %%
query = """
SELECT product, 
       SUM(quantity) AS total_qty, 
       SUM(quantity * price) AS revenue 
FROM sales 
GROUP BY product
"""

# %%
df = pd.read_sql_query(query, conn)

# %%
print(df)
# Out:
#          product  total_qty  revenue
# 0      Black Tea         21     37.8
# 1     Cappuccino         30    126.0
# 2         Coffee         45    112.5
# 3       Espresso         21     63.0
# 4      Green Tea         27     54.0
# 5     Herbal Tea         16     35.2
# 6  Hot Chocolate         38    133.0
# 7          Latte         33    132.0
# 8          Mocha         35    157.5
# 9            Tea         38     57.0

# %%
df.plot(kind='bar', x='product', y='revenue')
plt.title("Revenue by Product")
plt.xlabel("Product")
plt.ylabel("Revenue")
plt.tight_layout()
plt.savefig("sales_chart.png")  # Optional: Save chart
plt.show()

# %%
conn.close()
